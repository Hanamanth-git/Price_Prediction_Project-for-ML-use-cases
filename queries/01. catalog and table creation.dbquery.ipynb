-- %%
create catalog if not exists pricing_analytics;

create schema if not exists pricing_analytics.bronze;

create schema if not exists pricing_analytics.silver;

create schema if not exists pricing_analytics.gold;

create schema if not exists pricing_analytics.storageAC;

create volume if not exists pricing_analytics.storageAC.Pricing_analytics;

create table if not exists pricing_analytics.gold.product_scdtype2_dim(
PRODUCT_NAME string,
PRODUCTGROUP_NAME string,
PRODUCT_ID bigint,
RECORD_STATUS string,
effective_start_date timestamp,
effective_end_date timestamp,
lake_house_inserted_date timestamp,
lake_house_updated_date timestamp
);
