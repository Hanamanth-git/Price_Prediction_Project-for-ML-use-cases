-- %%
create table if not exists pricing_analytics.gold.state_dim(
STATE_NAME string,
STATE_ID bigint,
lake_house_inserted_date timestamp,
lake_house_updated_date timestamp
);

create table if not exists pricing_analytics.gold.market_dim(
MARKET_NAME string,
MARKET_ID bigint,
lake_house_inserted_date timestamp,
lake_house_updated_date timestamp
);

create table if not exists pricing_analytics.gold.product_dim(
PRODUCT_NAME string,
PRODUCTGROUP_NAME string,
PRODUCT_ID bigint,
lake_house_inserted_date timestamp,
lake_house_updated_date timestamp
);

create table if not exists pricing_analytics.gold.product_scdtype1_dim(
PRODUCT_NAME string,
PRODUCTGROUP_NAME string,
PRODUCT_ID bigint,
RECORD_STATUS string,
lake_house_inserted_date timestamp,
lake_house_updated_date timestamp
);
