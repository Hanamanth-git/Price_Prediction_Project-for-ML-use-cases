-- %%
create table if not exists pricing_analytics.bronze.pipeline_control_logs(
    process_name string,
    process_table_date_time timestamp,
    process_status string,
    process_log timestamp
);

create table if not exists pricing_analytics.bronze.file_process_control_logs(
    process_name string,
    Folder_name string,
    File_name string,
    File_status string,
    Reason String,
    File_process_log timestamp
);

create table if not exists pricing_analytics.bronze.file_process_data_count_log(
    process_name string,
    file_name string,
    Total_count bigint,
    Valid_count bigint,
    Quarntine_count bigint,
    process_timestamp timestamp
)
